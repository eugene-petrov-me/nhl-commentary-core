# %%
from nhlpy import NHLClient
import json
import pandas as pd
from typing import List, Dict, Any, Optional

# Initialize the NHL API client
client = NHLClient()

# Example: Fetch play-by-play data for a specific game
game_id = 2024030323  # Replace with a valid game ID
play_by_play_data = client.game_center.play_by_play(game_id)
print("Play-by-Play Data:") 
print(json.dumps(play_by_play_data, indent=2))
# Out:
# Play-by-Play Data:
# {
#   "id": 2024030323,
#   "season": 20242025,
#   "gameType": 3,
#   "limitedScoring": false,
#   "gameDate": "2025-05-25",
#   "venue": {
#     "default": "Rogers Place"
#   },
#   "venueLocation": {
#     "default": "Edmonton"
#   },
#   "startTimeUTC": "2025-05-25T19:00:00Z",
#   "easternUTCOffset": "-04:00",
#   "venueUTCOffset": "-06:00",
#   "tvBroadcasts": [
#     {
#       "id": 384,
#       "market": "N",
#       "countryCode": "US",
#       "network": "ABC",
#       "sequenceNumber": 1
#     },
#     {
#       "id": 329,
#       "market": "N",
#       "countryCode": "US",
#       "network": "ESPN+",
#       "sequenceNumber": 16
#     },
#     {
#       "id": 4,
#       "market": "N",
#       "countryCode": "CA",
#       "network": "CBC",
#       "sequenceNumber": 25
#     },
#     {
#       "id": 282,
#       "market": "N",
#       "countryCode": "CA",
#       "network": "SN",
#       "sequenceNumber": 101
#     },
#     {
#       "id": 281,
#       "market": "N",
#       "countryCode": "CA",
#       "network": "TVAS",
#       "sequenceNumber": 109
#     }
#   ],
#   "gameState": "OFF",
#   "gameScheduleState": "OK",
#   "periodDescriptor": {
#     "number": 3,
#     "periodType": "REG",
#     "maxRegulationPeriods": 3
#   },
#   "awayTeam": {
#     "id": 25,
#     "commonName": {
#       "default": "Stars"
#     },
#     "abbrev": "DAL",
#     "score": 1,
#     "sog": 34,
#     "logo": "https://assets.nhle.com/logos/nhl/svg/DAL_light.svg",
#     "darkLogo": "https://assets.nhle.com/logos/nhl/svg/DAL_dark.svg",
#     "placeName": {
#       "default": "Dallas"
#     },
#     "placeNameWithPreposition": {
#       "default": "Dallas",
#       "fr": "de Dallas"
#     }
#   },
#   "homeTeam": {
#     "id": 22,
#     "commonName": {
#       "default": "Oilers"
#     },
#     "abbrev": "EDM",
#     "score": 6,
#     "sog": 24,
#     "logo": "https://assets.nhle.com/logos/nhl/svg/EDM_light.svg",
#     "darkLogo": "https://assets.nhle.com/logos/nhl/svg/EDM_dark.svg",
#     "placeName": {
#       "default": "Edmonton"
#     },
#     "placeNameWithPreposition": {
#       "default": "Edmonton",
#       "fr": "d'Edmonton"
#     }
#   },
#   "shootoutInUse": false,
#   "otInUse": true,
#   "clock": {
#     "timeRemaining": "00:00",
#     "secondsRemaining": 0,
#     "running": false,
#     "inIntermission": false
#   },
#   "displayPeriod": 1,
#   "gameOutcome": {
#     "lastPeriodType": "REG"
#   },
#   "plays": [
#     {
#       "eventId": 52,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "00:00",
#       "timeRemaining": "20:00",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 520,
#       "typeDescKey": "period-start",
#       "sortOrder": 8
#     },
#     {
#       "eventId": 51,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "00:00",
#       "timeRemaining": "20:00",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 502,
#       "typeDescKey": "faceoff",
#       "sortOrder": 11,
#       "details": {
#         "eventOwnerTeamId": 25,
#         "losingPlayerId": 8477934,
#         "winningPlayerId": 8482740,
#         "xCoord": 0,
#         "yCoord": 0,
#         "zoneCode": "N"
#       }
#     },
#     {
#       "eventId": 64,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "00:05",
#       "timeRemaining": "19:55",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 504,
#       "typeDescKey": "giveaway",
#       "sortOrder": 12,
#       "details": {
#         "xCoord": -26,
#         "yCoord": -36,
#         "zoneCode": "D",
#         "eventOwnerTeamId": 22,
#         "playerId": 8476967
#       }
#     },
#     {
#       "eventId": 55,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "00:23",
#       "timeRemaining": "19:37",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 506,
#       "typeDescKey": "shot-on-goal",
#       "sortOrder": 13,
#       "details": {
#         "xCoord": 81,
#         "yCoord": 3,
#         "zoneCode": "O",
#         "shotType": "tip-in",
#         "shootingPlayerId": 8477953,
#         "goalieInNetId": 8479979,
#         "eventOwnerTeamId": 22,
#         "awaySOG": 0,
#         "homeSOG": 1
#       }
#     },
#     {
#       "eventId": 75,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "00:55",
#       "timeRemaining": "19:05",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 22,
#       "details": {
#         "xCoord": -42,
#         "yCoord": 40,
#         "zoneCode": "D",
#         "eventOwnerTeamId": 22,
#         "hittingPlayerId": 8476454,
#         "hitteePlayerId": 8476879
#       }
#     },
#     {
#       "eventId": 65,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "01:06",
#       "timeRemaining": "18:54",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 506,
#       "typeDescKey": "shot-on-goal",
#       "sortOrder": 23,
#       "details": {
#         "xCoord": -87,
#         "yCoord": -17,
#         "zoneCode": "O",
#         "shotType": "snap",
#         "shootingPlayerId": 8475798,
#         "goalieInNetId": 8479973,
#         "eventOwnerTeamId": 25,
#         "awaySOG": 1,
#         "homeSOG": 1
#       }
#     },
#     {
#       "eventId": 66,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "01:13",
#       "timeRemaining": "18:47",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 507,
#       "typeDescKey": "missed-shot",
#       "sortOrder": 24,
#       "details": {
#         "xCoord": 91,
#         "yCoord": 15,
#         "zoneCode": "O",
#         "reason": "hit-left-post",
#         "shotType": "wrist",
#         "shootingPlayerId": 8478402,
#         "goalieInNetId": 8479979,
#         "eventOwnerTeamId": 22
#       }
#     },
#     {
#       "eventId": 80,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "01:16",
#       "timeRemaining": "18:44",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 504,
#       "typeDescKey": "giveaway",
#       "sortOrder": 25,
#       "details": {
#         "xCoord": 98,
#         "yCoord": 18,
#         "zoneCode": "O",
#         "eventOwnerTeamId": 22,
#         "playerId": 8476454
#       }
#     },
#     {
#       "eventId": 92,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "01:18",
#       "timeRemaining": "18:42",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 26,
#       "details": {
#         "xCoord": 91,
#         "yCoord": 7,
#         "zoneCode": "O",
#         "eventOwnerTeamId": 22,
#         "hittingPlayerId": 8475786,
#         "hitteePlayerId": 8480027
#       }
#     },
#     {
#       "eventId": 97,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "01:22",
#       "timeRemaining": "18:38",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 27,
#       "details": {
#         "xCoord": 48,
#         "yCoord": 40,
#         "zoneCode": "O",
#         "eventOwnerTeamId": 22,
#         "hittingPlayerId": 8478013,
#         "hitteePlayerId": 8478420
#       }
#     },
#     {
#       "eventId": 8,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "01:26",
#       "timeRemaining": "18:34",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 516,
#       "typeDescKey": "stoppage",
#       "sortOrder": 30,
#       "details": {
#         "reason": "icing"
#       }
#     },
#     {
#       "eventId": 71,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "01:26",
#       "timeRemaining": "18:34",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 502,
#       "typeDescKey": "faceoff",
#       "sortOrder": 33,
#       "details": {
#         "eventOwnerTeamId": 25,
#         "losingPlayerId": 8474641,
#         "winningPlayerId": 8475798,
#         "xCoord": 69,
#         "yCoord": 22,
#         "zoneCode": "D"
#       }
#     },
#     {
#       "eventId": 151,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "01:43",
#       "timeRemaining": "18:17",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 507,
#       "typeDescKey": "missed-shot",
#       "sortOrder": 38,
#       "details": {
#         "xCoord": 38,
#         "yCoord": -1,
#         "zoneCode": "O",
#         "reason": "short",
#         "shotType": "wrist",
#         "shootingPlayerId": 8474641,
#         "goalieInNetId": 8479979,
#         "eventOwnerTeamId": 22
#       }
#     },
#     {
#       "eventId": 82,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "01:59",
#       "timeRemaining": "18:01",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 506,
#       "typeDescKey": "shot-on-goal",
#       "sortOrder": 39,
#       "details": {
#         "xCoord": -58,
#         "yCoord": -37,
#         "zoneCode": "O",
#         "shotType": "snap",
#         "shootingPlayerId": 8483425,
#         "goalieInNetId": 8479973,
#         "eventOwnerTeamId": 25,
#         "awaySOG": 2,
#         "homeSOG": 1
#       }
#     },
#     {
#       "eventId": 83,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "02:04",
#       "timeRemaining": "17:56",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 506,
#       "typeDescKey": "shot-on-goal",
#       "sortOrder": 40,
#       "details": {
#         "xCoord": -68,
#         "yCoord": -14,
#         "zoneCode": "O",
#         "shotType": "tip-in",
#         "shootingPlayerId": 8476278,
#         "goalieInNetId": 8479973,
#         "eventOwnerTeamId": 25,
#         "awaySOG": 3,
#         "homeSOG": 1
#       }
#     },
#     {
#       "eventId": 84,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "02:13",
#       "timeRemaining": "17:47",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 508,
#       "typeDescKey": "blocked-shot",
#       "sortOrder": 41,
#       "details": {
#         "xCoord": -76,
#         "yCoord": -11,
#         "zoneCode": "D",
#         "blockingPlayerId": 8475906,
#         "shootingPlayerId": 8483425,
#         "eventOwnerTeamId": 25,
#         "reason": "blocked"
#       }
#     },
#     {
#       "eventId": 116,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "02:25",
#       "timeRemaining": "17:35",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 48,
#       "details": {
#         "xCoord": 22,
#         "yCoord": -32,
#         "zoneCode": "N",
#         "eventOwnerTeamId": 25,
#         "hittingPlayerId": 8483425,
#         "hitteePlayerId": 8475906
#       }
#     },
#     {
#       "eventId": 95,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "02:43",
#       "timeRemaining": "17:17",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 507,
#       "typeDescKey": "missed-shot",
#       "sortOrder": 52,
#       "details": {
#         "xCoord": 36,
#         "yCoord": -29,
#         "zoneCode": "O",
#         "reason": "wide-left",
#         "shotType": "snap",
#         "shootingPlayerId": 8470621,
#         "goalieInNetId": 8479979,
#         "eventOwnerTeamId": 22
#       }
#     },
#     {
#       "eventId": 121,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "02:47",
#       "timeRemaining": "17:13",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 53,
#       "details": {
#         "xCoord": 74,
#         "yCoord": 37,
#         "zoneCode": "D",
#         "eventOwnerTeamId": 25,
#         "hittingPlayerId": 8475168,
#         "hitteePlayerId": 8479365
#       }
#     },
#     {
#       "eventId": 9,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "03:08",
#       "timeRemaining": "16:52",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 516,
#       "typeDescKey": "stoppage",
#       "sortOrder": 60,
#       "details": {
#         "reason": "icing"
#       }
#     },
#     {
#       "eventId": 102,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "03:08",
#       "timeRemaining": "16:52",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 502,
#       "typeDescKey": "faceoff",
#       "sortOrder": 61,
#       "details": {
#         "eventOwnerTeamId": 22,
#         "losingPlayerId": 8475794,
#         "winningPlayerId": 8477934,
#         "xCoord": 69,
#         "yCoord": 22,
#         "zoneCode": "O"
#       }
#     },
#     {
#       "eventId": 136,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "03:13",
#       "timeRemaining": "16:47",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 62,
#       "details": {
#         "xCoord": 95,
#         "yCoord": -20,
#         "zoneCode": "O",
#         "eventOwnerTeamId": 22,
#         "hittingPlayerId": 8481617,
#         "hitteePlayerId": 8476902
#       }
#     },
#     {
#       "eventId": 147,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "03:14",
#       "timeRemaining": "16:46",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 63,
#       "details": {
#         "xCoord": 65,
#         "yCoord": -38,
#         "zoneCode": "O",
#         "eventOwnerTeamId": 22,
#         "hittingPlayerId": 8475906,
#         "hitteePlayerId": 8473994
#       }
#     },
#     {
#       "eventId": 110,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "03:50",
#       "timeRemaining": "16:10",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 508,
#       "typeDescKey": "blocked-shot",
#       "sortOrder": 69,
#       "details": {
#         "xCoord": 78,
#         "yCoord": -12,
#         "zoneCode": "D",
#         "blockingPlayerId": 8477934,
#         "shootingPlayerId": 8481617,
#         "eventOwnerTeamId": 22,
#         "reason": "teammate-blocked"
#       }
#     },
#     {
#       "eventId": 203,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "04:04",
#       "timeRemaining": "15:56",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 74,
#       "details": {
#         "xCoord": -49,
#         "yCoord": -39,
#         "zoneCode": "D",
#         "eventOwnerTeamId": 22,
#         "hittingPlayerId": 8477953,
#         "hitteePlayerId": 8478420
#       }
#     },
#     {
#       "eventId": 118,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "04:21",
#       "timeRemaining": "15:39",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 506,
#       "typeDescKey": "shot-on-goal",
#       "sortOrder": 76,
#       "details": {
#         "xCoord": 54,
#         "yCoord": 29,
#         "zoneCode": "O",
#         "shotType": "wrist",
#         "shootingPlayerId": 8476454,
#         "goalieInNetId": 8479979,
#         "eventOwnerTeamId": 22,
#         "awaySOG": 3,
#         "homeSOG": 2
#       }
#     },
#     {
#       "eventId": 140,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "04:24",
#       "timeRemaining": "15:36",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 504,
#       "typeDescKey": "giveaway",
#       "sortOrder": 77,
#       "details": {
#         "xCoord": 77,
#         "yCoord": 6,
#         "zoneCode": "D",
#         "eventOwnerTeamId": 25,
#         "playerId": 8481581
#       }
#     },
#     {
#       "eventId": 119,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "04:29",
#       "timeRemaining": "15:31",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 506,
#       "typeDescKey": "shot-on-goal",
#       "sortOrder": 78,
#       "details": {
#         "xCoord": 37,
#         "yCoord": -18,
#         "zoneCode": "O",
#         "shotType": "slap",
#         "shootingPlayerId": 8480803,
#         "goalieInNetId": 8479979,
#         "eventOwnerTeamId": 22,
#         "awaySOG": 3,
#         "homeSOG": 3
#       }
#     },
#     {
#       "eventId": 124,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "04:59",
#       "timeRemaining": "15:01",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 506,
#       "typeDescKey": "shot-on-goal",
#       "sortOrder": 81,
#       "details": {
#         "xCoord": 68,
#         "yCoord": -14,
#         "zoneCode": "O",
#         "shotType": "snap",
#         "shootingPlayerId": 8475169,
#         "goalieInNetId": 8479979,
#         "eventOwnerTeamId": 22,
#         "awaySOG": 3,
#         "homeSOG": 4
#       }
#     },
#     {
#       "eventId": 126,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "05:19",
#       "timeRemaining": "14:41",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 506,
#       "typeDescKey": "shot-on-goal",
#       "sortOrder": 82,
#       "details": {
#         "xCoord": 83,
#         "yCoord": 16,
#         "zoneCode": "O",
#         "shotType": "wrist",
#         "shootingPlayerId": 8475786,
#         "goalieInNetId": 8479979,
#         "eventOwnerTeamId": 22,
#         "awaySOG": 3,
#         "homeSOG": 5
#       }
#     },
#     {
#       "eventId": 205,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "05:31",
#       "timeRemaining": "14:29",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 90,
#       "details": {
#         "xCoord": -52,
#         "yCoord": 38,
#         "zoneCode": "O",
#         "eventOwnerTeamId": 25,
#         "hittingPlayerId": 8476278,
#         "hitteePlayerId": 8479442
#       }
#     },
#     {
#       "eventId": 208,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "05:46",
#       "timeRemaining": "14:14",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 91,
#       "details": {
#         "xCoord": -94,
#         "yCoord": 30,
#         "zoneCode": "D",
#         "eventOwnerTeamId": 22,
#         "hittingPlayerId": 8477498,
#         "hitteePlayerId": 8480840
#       }
#     },
#     {
#       "eventId": 135,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "05:51",
#       "timeRemaining": "14:09",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 507,
#       "typeDescKey": "missed-shot",
#       "sortOrder": 92,
#       "details": {
#         "xCoord": -75,
#         "yCoord": -21,
#         "zoneCode": "O",
#         "reason": "hit-crossbar",
#         "shotType": "snap",
#         "shootingPlayerId": 8479351,
#         "goalieInNetId": 8479973,
#         "eventOwnerTeamId": 25
#       }
#     },
#     {
#       "eventId": 137,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "05:55",
#       "timeRemaining": "14:05",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 506,
#       "typeDescKey": "shot-on-goal",
#       "sortOrder": 93,
#       "details": {
#         "xCoord": -72,
#         "yCoord": 40,
#         "zoneCode": "O",
#         "shotType": "wrist",
#         "shootingPlayerId": 8475755,
#         "goalieInNetId": 8479973,
#         "eventOwnerTeamId": 25,
#         "awaySOG": 4,
#         "homeSOG": 5
#       }
#     },
#     {
#       "eventId": 10,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "06:25",
#       "timeRemaining": "13:35",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 516,
#       "typeDescKey": "stoppage",
#       "sortOrder": 99,
#       "details": {
#         "reason": "icing"
#       }
#     },
#     {
#       "eventId": 144,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "06:25",
#       "timeRemaining": "13:35",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 502,
#       "typeDescKey": "faceoff",
#       "sortOrder": 101,
#       "details": {
#         "eventOwnerTeamId": 22,
#         "losingPlayerId": 8475794,
#         "winningPlayerId": 8477934,
#         "xCoord": 69,
#         "yCoord": 22,
#         "zoneCode": "O"
#       }
#     },
#     {
#       "eventId": 229,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "06:38",
#       "timeRemaining": "13:22",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 104,
#       "details": {
#         "xCoord": -26,
#         "yCoord": -40,
#         "zoneCode": "D",
#         "eventOwnerTeamId": 22,
#         "hittingPlayerId": 8475906,
#         "hitteePlayerId": 8478975
#       }
#     },
#     {
#       "eventId": 11,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "06:39",
#       "timeRemaining": "13:21",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 516,
#       "typeDescKey": "stoppage",
#       "sortOrder": 105,
#       "details": {
#         "reason": "offside",
#         "secondaryReason": "tv-timeout"
#       }
#     },
#     {
#       "eventId": 149,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "06:39",
#       "timeRemaining": "13:21",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 502,
#       "typeDescKey": "faceoff",
#       "sortOrder": 108,
#       "details": {
#         "eventOwnerTeamId": 22,
#         "losingPlayerId": 8475168,
#         "winningPlayerId": 8477934,
#         "xCoord": -20,
#         "yCoord": -22,
#         "zoneCode": "N"
#       }
#     },
#     {
#       "eventId": 206,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "06:51",
#       "timeRemaining": "13:09",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 507,
#       "typeDescKey": "missed-shot",
#       "sortOrder": 109,
#       "details": {
#         "xCoord": 81,
#         "yCoord": 7,
#         "zoneCode": "O",
#         "reason": "wide-right",
#         "shotType": "backhand",
#         "shootingPlayerId": 8477934,
#         "goalieInNetId": 8479979,
#         "eventOwnerTeamId": 22
#       }
#     },
#     {
#       "eventId": 244,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "07:01",
#       "timeRemaining": "12:59",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 110,
#       "details": {
#         "xCoord": 88,
#         "yCoord": 36,
#         "zoneCode": "O",
#         "eventOwnerTeamId": 22,
#         "hittingPlayerId": 8481617,
#         "hitteePlayerId": 8480036
#       }
#     },
#     {
#       "eventId": 265,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "07:43",
#       "timeRemaining": "12:17",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 121,
#       "details": {
#         "xCoord": 10,
#         "yCoord": 40,
#         "zoneCode": "N",
#         "eventOwnerTeamId": 22,
#         "hittingPlayerId": 8479365,
#         "hitteePlayerId": 8473994
#       }
#     },
#     {
#       "eventId": 228,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "07:53",
#       "timeRemaining": "12:07",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 504,
#       "typeDescKey": "giveaway",
#       "sortOrder": 122,
#       "details": {
#         "xCoord": 5,
#         "yCoord": -31,
#         "zoneCode": "N",
#         "eventOwnerTeamId": 22,
#         "playerId": 8477406
#       }
#     },
#     {
#       "eventId": 231,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "08:12",
#       "timeRemaining": "11:48",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 504,
#       "typeDescKey": "giveaway",
#       "sortOrder": 130,
#       "details": {
#         "xCoord": -74,
#         "yCoord": 21,
#         "zoneCode": "D",
#         "eventOwnerTeamId": 22,
#         "playerId": 8476967
#       }
#     },
#     {
#       "eventId": 12,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "08:18",
#       "timeRemaining": "11:42",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 516,
#       "typeDescKey": "stoppage",
#       "sortOrder": 131,
#       "details": {
#         "reason": "offside"
#       }
#     },
#     {
#       "eventId": 226,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "08:18",
#       "timeRemaining": "11:42",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 502,
#       "typeDescKey": "faceoff",
#       "sortOrder": 132,
#       "details": {
#         "eventOwnerTeamId": 22,
#         "losingPlayerId": 8475798,
#         "winningPlayerId": 8478402,
#         "xCoord": -20,
#         "yCoord": -22,
#         "zoneCode": "N"
#       }
#     },
#     {
#       "eventId": 268,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "08:23",
#       "timeRemaining": "11:37",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 133,
#       "details": {
#         "xCoord": -8,
#         "yCoord": 25,
#         "zoneCode": "N",
#         "eventOwnerTeamId": 25,
#         "hittingPlayerId": 8476879,
#         "hitteePlayerId": 8476454
#       }
#     },
#     {
#       "eventId": 13,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "08:33",
#       "timeRemaining": "11:27",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 516,
#       "typeDescKey": "stoppage",
#       "sortOrder": 134,
#       "details": {
#         "reason": "icing"
#       }
#     },
#     {
#       "eventId": 230,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "08:33",
#       "timeRemaining": "11:27",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 502,
#       "typeDescKey": "faceoff",
#       "sortOrder": 135,
#       "details": {
#         "eventOwnerTeamId": 25,
#         "losingPlayerId": 8478402,
#         "winningPlayerId": 8475798,
#         "xCoord": 69,
#         "yCoord": 22,
#         "zoneCode": "D"
#       }
#     },
#     {
#       "eventId": 233,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "08:41",
#       "timeRemaining": "11:19",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 506,
#       "typeDescKey": "shot-on-goal",
#       "sortOrder": 136,
#       "details": {
#         "xCoord": 33,
#         "yCoord": -11,
#         "zoneCode": "O",
#         "shotType": "wrist",
#         "shootingPlayerId": 8476454,
#         "goalieInNetId": 8479979,
#         "eventOwnerTeamId": 22,
#         "awaySOG": 4,
#         "homeSOG": 6
#       }
#     },
#     {
#       "eventId": 272,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "08:46",
#       "timeRemaining": "11:14",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 137,
#       "details": {
#         "xCoord": 26,
#         "yCoord": 40,
#         "zoneCode": "O",
#         "eventOwnerTeamId": 22,
#         "hittingPlayerId": 8475786,
#         "hitteePlayerId": 8478420
#       }
#     },
#     {
#       "eventId": 274,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "09:07",
#       "timeRemaining": "10:53",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 145,
#       "details": {
#         "xCoord": -99,
#         "yCoord": -15,
#         "zoneCode": "O",
#         "eventOwnerTeamId": 25,
#         "hittingPlayerId": 8479351,
#         "hitteePlayerId": 8478013
#       }
#     },
#     {
#       "eventId": 241,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "09:12",
#       "timeRemaining": "10:48",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 506,
#       "typeDescKey": "shot-on-goal",
#       "sortOrder": 146,
#       "details": {
#         "xCoord": -83,
#         "yCoord": -15,
#         "zoneCode": "O",
#         "shotType": "snap",
#         "shootingPlayerId": 8476278,
#         "goalieInNetId": 8479973,
#         "eventOwnerTeamId": 25,
#         "awaySOG": 5,
#         "homeSOG": 6
#       }
#     },
#     {
#       "eventId": 14,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "09:15",
#       "timeRemaining": "10:45",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 516,
#       "typeDescKey": "stoppage",
#       "sortOrder": 147,
#       "details": {
#         "reason": "puck-frozen"
#       }
#     },
#     {
#       "eventId": 242,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "09:15",
#       "timeRemaining": "10:45",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 502,
#       "typeDescKey": "faceoff",
#       "sortOrder": 150,
#       "details": {
#         "eventOwnerTeamId": 22,
#         "losingPlayerId": 8479351,
#         "winningPlayerId": 8474641,
#         "xCoord": -69,
#         "yCoord": -22,
#         "zoneCode": "D"
#       }
#     },
#     {
#       "eventId": 15,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "09:21",
#       "timeRemaining": "10:39",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 516,
#       "typeDescKey": "stoppage",
#       "sortOrder": 151,
#       "details": {
#         "reason": "puck-in-benches"
#       }
#     },
#     {
#       "eventId": 248,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "09:21",
#       "timeRemaining": "10:39",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 502,
#       "typeDescKey": "faceoff",
#       "sortOrder": 152,
#       "details": {
#         "eventOwnerTeamId": 25,
#         "losingPlayerId": 8474641,
#         "winningPlayerId": 8476278,
#         "xCoord": -69,
#         "yCoord": 22,
#         "zoneCode": "O"
#       }
#     },
#     {
#       "eventId": 257,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "09:25",
#       "timeRemaining": "10:35",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 504,
#       "typeDescKey": "giveaway",
#       "sortOrder": 153,
#       "details": {
#         "xCoord": -56,
#         "yCoord": -30,
#         "zoneCode": "D",
#         "eventOwnerTeamId": 22,
#         "playerId": 8477498
#       }
#     },
#     {
#       "eventId": 266,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "09:44",
#       "timeRemaining": "10:16",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 504,
#       "typeDescKey": "giveaway",
#       "sortOrder": 158,
#       "details": {
#         "xCoord": -99,
#         "yCoord": 2,
#         "zoneCode": "D",
#         "eventOwnerTeamId": 22,
#         "playerId": 8477498
#       }
#     },
#     {
#       "eventId": 261,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "10:08",
#       "timeRemaining": "09:52",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 506,
#       "typeDescKey": "shot-on-goal",
#       "sortOrder": 163,
#       "details": {
#         "xCoord": 10,
#         "yCoord": 33,
#         "zoneCode": "N",
#         "shotType": "deflected",
#         "shootingPlayerId": 8477953,
#         "goalieInNetId": 8479979,
#         "eventOwnerTeamId": 22,
#         "awaySOG": 5,
#         "homeSOG": 7
#       }
#     },
#     {
#       "eventId": 16,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "10:12",
#       "timeRemaining": "09:48",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 516,
#       "typeDescKey": "stoppage",
#       "sortOrder": 167,
#       "details": {
#         "reason": "goalie-stopped-after-sog",
#         "secondaryReason": "tv-timeout"
#       }
#     },
#     {
#       "eventId": 262,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "10:12",
#       "timeRemaining": "09:48",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 502,
#       "typeDescKey": "faceoff",
#       "sortOrder": 169,
#       "details": {
#         "eventOwnerTeamId": 22,
#         "losingPlayerId": 8482740,
#         "winningPlayerId": 8477934,
#         "xCoord": 69,
#         "yCoord": 22,
#         "zoneCode": "O"
#       }
#     },
#     {
#       "eventId": 269,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "10:13",
#       "timeRemaining": "09:47",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 506,
#       "typeDescKey": "shot-on-goal",
#       "sortOrder": 170,
#       "details": {
#         "xCoord": 56,
#         "yCoord": 17,
#         "zoneCode": "O",
#         "shotType": "snap",
#         "shootingPlayerId": 8477953,
#         "goalieInNetId": 8479979,
#         "eventOwnerTeamId": 22,
#         "awaySOG": 5,
#         "homeSOG": 8
#       }
#     },
#     {
#       "eventId": 17,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "10:15",
#       "timeRemaining": "09:45",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 516,
#       "typeDescKey": "stoppage",
#       "sortOrder": 171,
#       "details": {
#         "reason": "goalie-stopped-after-sog"
#       }
#     },
#     {
#       "eventId": 270,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "10:15",
#       "timeRemaining": "09:45",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 502,
#       "typeDescKey": "faceoff",
#       "sortOrder": 173,
#       "details": {
#         "eventOwnerTeamId": 25,
#         "losingPlayerId": 8477934,
#         "winningPlayerId": 8482740,
#         "xCoord": 69,
#         "yCoord": 22,
#         "zoneCode": "D"
#       }
#     },
#     {
#       "eventId": 288,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "10:31",
#       "timeRemaining": "09:29",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 504,
#       "typeDescKey": "giveaway",
#       "sortOrder": 174,
#       "details": {
#         "xCoord": 19,
#         "yCoord": 42,
#         "zoneCode": "N",
#         "eventOwnerTeamId": 25,
#         "playerId": 8476879
#       }
#     },
#     {
#       "eventId": 275,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "10:38",
#       "timeRemaining": "09:22",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 508,
#       "typeDescKey": "blocked-shot",
#       "sortOrder": 175,
#       "details": {
#         "xCoord": -66,
#         "yCoord": -15,
#         "zoneCode": "D",
#         "blockingPlayerId": 8475906,
#         "shootingPlayerId": 8481581,
#         "eventOwnerTeamId": 25,
#         "reason": "blocked"
#       }
#     },
#     {
#       "eventId": 295,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "11:10",
#       "timeRemaining": "08:50",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 504,
#       "typeDescKey": "giveaway",
#       "sortOrder": 184,
#       "details": {
#         "xCoord": 55,
#         "yCoord": -1,
#         "zoneCode": "O",
#         "eventOwnerTeamId": 22,
#         "playerId": 8478402
#       }
#     },
#     {
#       "eventId": 285,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "11:17",
#       "timeRemaining": "08:43",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 507,
#       "typeDescKey": "missed-shot",
#       "sortOrder": 185,
#       "details": {
#         "xCoord": -74,
#         "yCoord": 9,
#         "zoneCode": "O",
#         "reason": "wide-left",
#         "shotType": "tip-in",
#         "shootingPlayerId": 8480027,
#         "goalieInNetId": 8479973,
#         "eventOwnerTeamId": 25
#       }
#     },
#     {
#       "eventId": 296,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "11:22",
#       "timeRemaining": "08:38",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 504,
#       "typeDescKey": "giveaway",
#       "sortOrder": 186,
#       "details": {
#         "xCoord": -54,
#         "yCoord": -33,
#         "zoneCode": "D",
#         "eventOwnerTeamId": 22,
#         "playerId": 8476454
#       }
#     },
#     {
#       "eventId": 315,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "11:29",
#       "timeRemaining": "08:31",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 189,
#       "details": {
#         "xCoord": -73,
#         "yCoord": -38,
#         "zoneCode": "D",
#         "eventOwnerTeamId": 22,
#         "hittingPlayerId": 8476967,
#         "hitteePlayerId": 8480027
#       }
#     },
#     {
#       "eventId": 289,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "11:36",
#       "timeRemaining": "08:24",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 506,
#       "typeDescKey": "shot-on-goal",
#       "sortOrder": 191,
#       "details": {
#         "xCoord": 78,
#         "yCoord": -33,
#         "zoneCode": "O",
#         "shotType": "wrist",
#         "shootingPlayerId": 8475786,
#         "goalieInNetId": 8479979,
#         "eventOwnerTeamId": 22,
#         "awaySOG": 5,
#         "homeSOG": 9
#       }
#     },
#     {
#       "eventId": 18,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "11:38",
#       "timeRemaining": "08:22",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 516,
#       "typeDescKey": "stoppage",
#       "sortOrder": 192,
#       "details": {
#         "reason": "goalie-stopped-after-sog"
#       }
#     },
#     {
#       "eventId": 290,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "11:38",
#       "timeRemaining": "08:22",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 502,
#       "typeDescKey": "faceoff",
#       "sortOrder": 195,
#       "details": {
#         "eventOwnerTeamId": 25,
#         "losingPlayerId": 8477406,
#         "winningPlayerId": 8479351,
#         "xCoord": 69,
#         "yCoord": -22,
#         "zoneCode": "D"
#       }
#     },
#     {
#       "eventId": 298,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "12:14",
#       "timeRemaining": "07:46",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 508,
#       "typeDescKey": "blocked-shot",
#       "sortOrder": 197,
#       "details": {
#         "xCoord": 46,
#         "yCoord": 14,
#         "zoneCode": "D",
#         "blockingPlayerId": 8476879,
#         "shootingPlayerId": 8477498,
#         "eventOwnerTeamId": 22,
#         "reason": "blocked"
#       }
#     },
#     {
#       "eventId": 311,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "12:42",
#       "timeRemaining": "07:18",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 504,
#       "typeDescKey": "giveaway",
#       "sortOrder": 204,
#       "details": {
#         "xCoord": -10,
#         "yCoord": -35,
#         "zoneCode": "N",
#         "eventOwnerTeamId": 22,
#         "playerId": 8477015
#       }
#     },
#     {
#       "eventId": 324,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "12:54",
#       "timeRemaining": "07:06",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 205,
#       "details": {
#         "xCoord": 97,
#         "yCoord": -20,
#         "zoneCode": "O",
#         "eventOwnerTeamId": 22,
#         "hittingPlayerId": 8474641,
#         "hitteePlayerId": 8483425
#       }
#     },
#     {
#       "eventId": 326,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "12:55",
#       "timeRemaining": "07:05",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 206,
#       "details": {
#         "xCoord": 92,
#         "yCoord": 32,
#         "zoneCode": "O",
#         "eventOwnerTeamId": 22,
#         "hittingPlayerId": 8475169,
#         "hitteePlayerId": 8475755
#       }
#     },
#     {
#       "eventId": 19,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "13:52",
#       "timeRemaining": "06:08",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 516,
#       "typeDescKey": "stoppage",
#       "sortOrder": 216,
#       "details": {
#         "reason": "puck-in-netting"
#       }
#     },
#     {
#       "eventId": 317,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "13:52",
#       "timeRemaining": "06:08",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 502,
#       "typeDescKey": "faceoff",
#       "sortOrder": 218,
#       "details": {
#         "eventOwnerTeamId": 25,
#         "losingPlayerId": 8478402,
#         "winningPlayerId": 8482740,
#         "xCoord": -69,
#         "yCoord": 22,
#         "zoneCode": "O"
#       }
#     },
#     {
#       "eventId": 320,
#       "periodDescriptor": {
#         "number": 1,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "14:02",
#       "timeRemaining": "05:58",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 505,
#       "typeDescKey": "goal",
#       "sortOrder": 219,
#       "details": {
#         "xCoord": 38,
#         "yCoord": -25,
#         "zoneCode": "O",
#         "shotType": "slap",
#         "scoringPlayerId": 8480803,
#         "scoringPlayerTotal": 6,
#         "assist1PlayerId": 8476454,
#         "assist1PlayerTotal": 9,
#         "assist2PlayerId": 8476967,
#         "assist2PlayerTotal": 3,
#         "eventOwnerTeamId": 22,
#         "goalieInNetId": 8479979,
#         "awayScore": 0,
#         "homeScore": 1,
#         "highlightClipSharingUrl": "https://nhl.com/video/dal-edm-bouchard-scores-goal-against-jake-oettinger-6373473286112",
#         "highlightClipSharingUrlFr": "https://nhl.com/fr/video/dal-edm-bouchard-marque-un-but-contre-jake-oettinger-6373473783112",
#         "highlightClip": 6373473286112,
# ...
#       "homeTeamDefendingSide": "left",
#       "typeCode": 503,
#       "typeDescKey": "hit",
#       "sortOrder": 873,
#       "details": {
#         "xCoord": -97,
#         "yCoord": -11,
#         "zoneCode": "D",
#         "eventOwnerTeamId": 22,
#         "hittingPlayerId": 8475906,
#         "hitteePlayerId": 8480840
#       }
#     },
#     {
#       "eventId": 1204,
#       "periodDescriptor": {
#         "number": 3,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "19:15",
#       "timeRemaining": "00:45",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 525,
#       "typeDescKey": "takeaway",
#       "sortOrder": 874,
#       "details": {
#         "xCoord": 65,
#         "yCoord": 33,
#         "zoneCode": "D",
#         "playerId": 8476902,
#         "eventOwnerTeamId": 25
#       }
#     },
#     {
#       "eventId": 474,
#       "periodDescriptor": {
#         "number": 3,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "19:35",
#       "timeRemaining": "00:25",
#       "situationCode": "1551",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 509,
#       "typeDescKey": "penalty",
#       "sortOrder": 876,
#       "details": {
#         "xCoord": -25,
#         "yCoord": -37,
#         "zoneCode": "O",
#         "typeCode": "MIN",
#         "descKey": "roughing",
#         "duration": 2,
#         "committedByPlayerId": 8476278,
#         "drawnByPlayerId": 8477953,
#         "eventOwnerTeamId": 25
#       }
#     },
#     {
#       "eventId": 477,
#       "periodDescriptor": {
#         "number": 3,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "19:35",
#       "timeRemaining": "00:25",
#       "situationCode": "1451",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 509,
#       "typeDescKey": "penalty",
#       "sortOrder": 879,
#       "details": {
#         "xCoord": -27,
#         "yCoord": -36,
#         "zoneCode": "D",
#         "typeCode": "MIN",
#         "descKey": "roughing",
#         "duration": 2,
#         "committedByPlayerId": 8477953,
#         "drawnByPlayerId": 8476278,
#         "eventOwnerTeamId": 22
#       }
#     },
#     {
#       "eventId": 1150,
#       "periodDescriptor": {
#         "number": 3,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "19:35",
#       "timeRemaining": "00:25",
#       "situationCode": "1441",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 502,
#       "typeDescKey": "faceoff",
#       "sortOrder": 883,
#       "details": {
#         "eventOwnerTeamId": 25,
#         "losingPlayerId": 8474641,
#         "winningPlayerId": 8479351,
#         "xCoord": -20,
#         "yCoord": -22,
#         "zoneCode": "N"
#       }
#     },
#     {
#       "eventId": 481,
#       "periodDescriptor": {
#         "number": 3,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "20:00",
#       "timeRemaining": "00:00",
#       "situationCode": "1441",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 521,
#       "typeDescKey": "period-end",
#       "sortOrder": 884
#     },
#     {
#       "eventId": 485,
#       "periodDescriptor": {
#         "number": 3,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "timeInPeriod": "20:00",
#       "timeRemaining": "00:00",
#       "situationCode": "1441",
#       "homeTeamDefendingSide": "left",
#       "typeCode": 524,
#       "typeDescKey": "game-end",
#       "sortOrder": 888
#     }
#   ],
#   "rosterSpots": [
#     {
#       "teamId": 22,
#       "playerId": 8470621,
#       "firstName": {
#         "default": "Corey"
#       },
#       "lastName": {
#         "default": "Perry"
#       },
#       "sweaterNumber": 90,
#       "positionCode": "R",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8470621.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8473994,
#       "firstName": {
#         "default": "Jamie"
#       },
#       "lastName": {
#         "default": "Benn"
#       },
#       "sweaterNumber": 14,
#       "positionCode": "L",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8473994.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8474149,
#       "firstName": {
#         "default": "Evgenii",
#         "cs": "Jevgenij",
#         "fi": "Jevgeni",
#         "sk": "Jevgenij"
#       },
#       "lastName": {
#         "default": "Dadonov"
#       },
#       "sweaterNumber": 63,
#       "positionCode": "R",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8474149.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8474641,
#       "firstName": {
#         "default": "Adam"
#       },
#       "lastName": {
#         "default": "Henrique"
#       },
#       "sweaterNumber": 19,
#       "positionCode": "C",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8474641.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8475168,
#       "firstName": {
#         "default": "Matt"
#       },
#       "lastName": {
#         "default": "Duchene"
#       },
#       "sweaterNumber": 95,
#       "positionCode": "C",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8475168.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8475169,
#       "firstName": {
#         "default": "Evander"
#       },
#       "lastName": {
#         "default": "Kane"
#       },
#       "sweaterNumber": 91,
#       "positionCode": "L",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8475169.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8475755,
#       "firstName": {
#         "default": "Alexander",
#         "es": "Alex"
#       },
#       "lastName": {
#         "default": "Petrovic"
#       },
#       "sweaterNumber": 28,
#       "positionCode": "D",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8475755.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8475786,
#       "firstName": {
#         "default": "Zach"
#       },
#       "lastName": {
#         "default": "Hyman"
#       },
#       "sweaterNumber": 18,
#       "positionCode": "L",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8475786.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8475794,
#       "firstName": {
#         "default": "Tyler"
#       },
#       "lastName": {
#         "default": "Seguin"
#       },
#       "sweaterNumber": 91,
#       "positionCode": "C",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8475794.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8475798,
#       "firstName": {
#         "default": "Mikael"
#       },
#       "lastName": {
#         "default": "Granlund"
#       },
#       "sweaterNumber": 64,
#       "positionCode": "C",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8475798.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8475906,
#       "firstName": {
#         "default": "John"
#       },
#       "lastName": {
#         "default": "Klingberg"
#       },
#       "sweaterNumber": 36,
#       "positionCode": "D",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8475906.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8476278,
#       "firstName": {
#         "default": "Colin"
#       },
#       "lastName": {
#         "default": "Blackwell"
#       },
#       "sweaterNumber": 15,
#       "positionCode": "C",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8476278.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8476454,
#       "firstName": {
#         "default": "Ryan"
#       },
#       "lastName": {
#         "default": "Nugent-Hopkins"
#       },
#       "sweaterNumber": 93,
#       "positionCode": "C",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8476454.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8476879,
#       "firstName": {
#         "default": "Cody"
#       },
#       "lastName": {
#         "default": "Ceci"
#       },
#       "sweaterNumber": 44,
#       "positionCode": "D",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8476879.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8476902,
#       "firstName": {
#         "default": "Esa"
#       },
#       "lastName": {
#         "default": "Lindell"
#       },
#       "sweaterNumber": 23,
#       "positionCode": "D",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8476902.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8476967,
#       "firstName": {
#         "default": "Brett"
#       },
#       "lastName": {
#         "default": "Kulak"
#       },
#       "sweaterNumber": 27,
#       "positionCode": "D",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8476967.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8477015,
#       "firstName": {
#         "default": "Connor"
#       },
#       "lastName": {
#         "default": "Brown"
#       },
#       "sweaterNumber": 28,
#       "positionCode": "R",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8477015.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8477406,
#       "firstName": {
#         "default": "Mattias"
#       },
#       "lastName": {
#         "default": "Janmark"
#       },
#       "sweaterNumber": 13,
#       "positionCode": "C",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8477406.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8477498,
#       "firstName": {
#         "default": "Darnell"
#       },
#       "lastName": {
#         "default": "Nurse"
#       },
#       "sweaterNumber": 25,
#       "positionCode": "D",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8477498.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8477934,
#       "firstName": {
#         "default": "Leon"
#       },
#       "lastName": {
#         "default": "Draisaitl"
#       },
#       "sweaterNumber": 29,
#       "positionCode": "C",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8477934.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8477953,
#       "firstName": {
#         "default": "Kasperi"
#       },
#       "lastName": {
#         "default": "Kapanen"
#       },
#       "sweaterNumber": 42,
#       "positionCode": "R",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8477953.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8478013,
#       "firstName": {
#         "default": "Jake"
#       },
#       "lastName": {
#         "default": "Walman"
#       },
#       "sweaterNumber": 96,
#       "positionCode": "D",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8478013.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8478402,
#       "firstName": {
#         "default": "Connor"
#       },
#       "lastName": {
#         "default": "McDavid"
#       },
#       "sweaterNumber": 97,
#       "positionCode": "C",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8478402.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8478420,
#       "firstName": {
#         "default": "Mikko"
#       },
#       "lastName": {
#         "default": "Rantanen"
#       },
#       "sweaterNumber": 96,
#       "positionCode": "R",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8478420.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8478975,
#       "firstName": {
#         "default": "Mason"
#       },
#       "lastName": {
#         "default": "Marchment"
#       },
#       "sweaterNumber": 27,
#       "positionCode": "L",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8478975.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8479193,
#       "firstName": {
#         "default": "Casey"
#       },
#       "lastName": {
#         "default": "DeSmith"
#       },
#       "sweaterNumber": 1,
#       "positionCode": "G",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8479193.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8479351,
#       "firstName": {
#         "default": "Sam"
#       },
#       "lastName": {
#         "default": "Steel"
#       },
#       "sweaterNumber": 18,
#       "positionCode": "C",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8479351.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8479365,
#       "firstName": {
#         "default": "Trent"
#       },
#       "lastName": {
#         "default": "Frederic"
#       },
#       "sweaterNumber": 21,
#       "positionCode": "C",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8479365.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8479442,
#       "firstName": {
#         "default": "Troy"
#       },
#       "lastName": {
#         "default": "Stecher"
#       },
#       "sweaterNumber": 51,
#       "positionCode": "D",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8479442.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8479973,
#       "firstName": {
#         "default": "Stuart"
#       },
#       "lastName": {
#         "default": "Skinner"
#       },
#       "sweaterNumber": 74,
#       "positionCode": "G",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8479973.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8479979,
#       "firstName": {
#         "default": "Jake"
#       },
#       "lastName": {
#         "default": "Oettinger"
#       },
#       "sweaterNumber": 29,
#       "positionCode": "G",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8479979.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8480027,
#       "firstName": {
#         "default": "Jason"
#       },
#       "lastName": {
#         "default": "Robertson"
#       },
#       "sweaterNumber": 21,
#       "positionCode": "L",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8480027.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8480036,
#       "firstName": {
#         "default": "Miro"
#       },
#       "lastName": {
#         "default": "Heiskanen"
#       },
#       "sweaterNumber": 4,
#       "positionCode": "D",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8480036.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8480803,
#       "firstName": {
#         "default": "Evan"
#       },
#       "lastName": {
#         "default": "Bouchard"
#       },
#       "sweaterNumber": 2,
#       "positionCode": "D",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8480803.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8480840,
#       "firstName": {
#         "default": "Oskar"
#       },
#       "lastName": {
#         "default": "B\u00e4ck"
#       },
#       "sweaterNumber": 10,
#       "positionCode": "C",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8480840.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8480885,
#       "firstName": {
#         "default": "Olivier"
#       },
#       "lastName": {
#         "default": "Rodrigue"
#       },
#       "sweaterNumber": 35,
#       "positionCode": "G",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8480885.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8481581,
#       "firstName": {
#         "default": "Thomas"
#       },
#       "lastName": {
#         "default": "Harley"
#       },
#       "sweaterNumber": 55,
#       "positionCode": "D",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8481581.png"
#     },
#     {
#       "teamId": 22,
#       "playerId": 8481617,
#       "firstName": {
#         "default": "Vasily",
#         "cs": "Vasilij",
#         "fi": "Vasili",
#         "sk": "Vasilij"
#       },
#       "lastName": {
#         "default": "Podkolzin"
#       },
#       "sweaterNumber": 92,
#       "positionCode": "R",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8481617.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8482740,
#       "firstName": {
#         "default": "Wyatt"
#       },
#       "lastName": {
#         "default": "Johnston"
#       },
#       "sweaterNumber": 53,
#       "positionCode": "C",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8482740.png"
#     },
#     {
#       "teamId": 25,
#       "playerId": 8483425,
#       "firstName": {
#         "default": "Lian"
#       },
#       "lastName": {
#         "default": "Bichsel"
#       },
#       "sweaterNumber": 6,
#       "positionCode": "D",
#       "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8483425.png"
#     }
#   ],
#   "regPeriods": 3,
#   "summary": {}
# }

# %%
# Example: Fetch game story data for the same game
game_story_data = client.game_center.game_story(game_id)
print("\nGame Story Data:")
print(json.dumps(game_story_data, indent=2))
# Out:
# Game Story Data:
# {
#   "id": 2024030323,
#   "season": 20242025,
#   "gameType": 3,
#   "limitedScoring": false,
#   "gameDate": "2025-05-25",
#   "venue": {
#     "default": "Rogers Place"
#   },
#   "venueLocation": {
#     "default": "Edmonton"
#   },
#   "startTimeUTC": "2025-05-25T19:00:00Z",
#   "easternUTCOffset": "-04:00",
#   "venueUTCOffset": "-06:00",
#   "venueTimezone": "America/Edmonton",
#   "tvBroadcasts": [
#     {
#       "id": 4,
#       "market": "N",
#       "countryCode": "CA",
#       "network": "CBC",
#       "sequenceNumber": 25
#     },
#     {
#       "id": 281,
#       "market": "N",
#       "countryCode": "CA",
#       "network": "TVAS",
#       "sequenceNumber": 109
#     },
#     {
#       "id": 282,
#       "market": "N",
#       "countryCode": "CA",
#       "network": "SN",
#       "sequenceNumber": 101
#     },
#     {
#       "id": 329,
#       "market": "N",
#       "countryCode": "US",
#       "network": "ESPN+",
#       "sequenceNumber": 16
#     },
#     {
#       "id": 384,
#       "market": "N",
#       "countryCode": "US",
#       "network": "ABC",
#       "sequenceNumber": 1
#     }
#   ],
#   "gameState": "OFF",
#   "gameScheduleState": "OK",
#   "awayTeam": {
#     "id": 25,
#     "name": {
#       "default": "Stars"
#     },
#     "abbrev": "DAL",
#     "placeName": {
#       "default": "Dallas"
#     },
#     "score": 1,
#     "sog": 34,
#     "logo": "https://assets.nhle.com/logos/nhl/svg/DAL_light.svg"
#   },
#   "homeTeam": {
#     "id": 22,
#     "name": {
#       "default": "Oilers"
#     },
#     "abbrev": "EDM",
#     "placeName": {
#       "default": "Edmonton"
#     },
#     "score": 6,
#     "sog": 24,
#     "logo": "https://assets.nhle.com/logos/nhl/svg/EDM_light.svg"
#   },
#   "shootoutInUse": false,
#   "regPeriods": 3,
#   "otInUse": true,
#   "tiesInUse": false,
#   "summary": {
#     "scoring": [
#       {
#         "periodDescriptor": {
#           "number": 1,
#           "periodType": "REG",
#           "maxRegulationPeriods": 3
#         },
#         "goals": [
#           {
#             "situationCode": "1551",
#             "eventId": 320,
#             "strength": "ev",
#             "playerId": 8480803,
#             "firstName": {
#               "default": "Evan"
#             },
#             "lastName": {
#               "default": "Bouchard"
#             },
#             "name": {
#               "default": "E. Bouchard"
#             },
#             "teamAbbrev": {
#               "default": "EDM"
#             },
#             "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8480803.png",
#             "highlightClipSharingUrl": "https://nhl.com/video/dal-edm-bouchard-scores-goal-against-jake-oettinger-6373473286112",
#             "highlightClipSharingUrlFr": "https://nhl.com/fr/video/dal-edm-bouchard-marque-un-but-contre-jake-oettinger-6373473783112",
#             "highlightClip": 6373473286112,
#             "highlightClipFr": 6373473783112,
#             "discreteClip": 6373475625112,
#             "discreteClipFr": 6373473285112,
#             "goalsToDate": 6,
#             "awayScore": 0,
#             "homeScore": 1,
#             "leadingTeamAbbrev": {
#               "default": "EDM"
#             },
#             "timeInPeriod": "14:02",
#             "shotType": "slap",
#             "goalModifier": "none",
#             "assists": [
#               {
#                 "playerId": 8476454,
#                 "firstName": {
#                   "default": "Ryan"
#                 },
#                 "lastName": {
#                   "default": "Nugent-Hopkins"
#                 },
#                 "name": {
#                   "default": "R. Nugent-Hopkins"
#                 },
#                 "assistsToDate": 9,
#                 "sweaterNumber": 93
#               },
#               {
#                 "playerId": 8476967,
#                 "firstName": {
#                   "default": "Brett"
#                 },
#                 "lastName": {
#                   "default": "Kulak"
#                 },
#                 "name": {
#                   "default": "B. Kulak"
#                 },
#                 "assistsToDate": 3,
#                 "sweaterNumber": 27
#               }
#             ],
#             "homeTeamDefendingSide": "left",
#             "isHome": true
#           },
#           {
#             "situationCode": "1551",
#             "eventId": 327,
#             "strength": "ev",
#             "playerId": 8478402,
#             "firstName": {
#               "default": "Connor"
#             },
#             "lastName": {
#               "default": "McDavid"
#             },
#             "name": {
#               "default": "C. McDavid"
#             },
#             "teamAbbrev": {
#               "default": "EDM"
#             },
#             "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8478402.png",
#             "highlightClipSharingUrl": "https://nhl.com/video/dal-edm-mcdavid-scores-goal-against-jake-oettinger-6373476028112",
#             "highlightClipSharingUrlFr": "https://nhl.com/fr/video/dal-edm-mcdavid-marque-un-but-contre-jake-oettinger-6373475258112",
#             "highlightClip": 6373476028112,
#             "highlightClipFr": 6373475258112,
#             "discreteClip": 6373476029112,
#             "discreteClipFr": 6373474462112,
#             "goalsToDate": 4,
#             "awayScore": 0,
#             "homeScore": 2,
#             "leadingTeamAbbrev": {
#               "default": "EDM"
#             },
#             "timeInPeriod": "14:38",
#             "shotType": "snap",
#             "goalModifier": "none",
#             "assists": [
#               {
#                 "playerId": 8476454,
#                 "firstName": {
#                   "default": "Ryan"
#                 },
#                 "lastName": {
#                   "default": "Nugent-Hopkins"
#                 },
#                 "name": {
#                   "default": "R. Nugent-Hopkins"
#                 },
#                 "assistsToDate": 10,
#                 "sweaterNumber": 93
#               },
#               {
#                 "playerId": 8475786,
#                 "firstName": {
#                   "default": "Zach"
#                 },
#                 "lastName": {
#                   "default": "Hyman"
#                 },
#                 "name": {
#                   "default": "Z. Hyman"
#                 },
#                 "assistsToDate": 6,
#                 "sweaterNumber": 18
#               }
#             ],
#             "homeTeamDefendingSide": "left",
#             "isHome": true
#           }
#         ]
#       },
#       {
#         "periodDescriptor": {
#           "number": 2,
#           "periodType": "REG",
#           "maxRegulationPeriods": 3
#         },
#         "goals": [
#           {
#             "situationCode": "1551",
#             "eventId": 745,
#             "strength": "ev",
#             "playerId": 8480027,
#             "firstName": {
#               "default": "Jason"
#             },
#             "lastName": {
#               "default": "Robertson"
#             },
#             "name": {
#               "default": "J. Robertson"
#             },
#             "teamAbbrev": {
#               "default": "DAL"
#             },
#             "headshot": "https://assets.nhle.com/mugs/nhl/20242025/DAL/8480027.png",
#             "highlightClipSharingUrl": "https://nhl.com/video/dal-edm-robertson-scores-goal-against-stuart-skinner-6373475880112",
#             "highlightClipSharingUrlFr": "https://nhl.com/fr/video/dal-edm-robertson-marque-un-but-contre-stuart-skinner-6373475970112",
#             "highlightClip": 6373475880112,
#             "highlightClipFr": 6373475970112,
#             "discreteClip": 6373476361112,
#             "discreteClipFr": 6373477542112,
#             "goalsToDate": 1,
#             "awayScore": 1,
#             "homeScore": 2,
#             "leadingTeamAbbrev": {
#               "default": "EDM"
#             },
#             "timeInPeriod": "15:35",
#             "shotType": "tip-in",
#             "goalModifier": "none",
#             "assists": [
#               {
#                 "playerId": 8483425,
#                 "firstName": {
#                   "default": "Lian"
#                 },
#                 "lastName": {
#                   "default": "Bichsel"
#                 },
#                 "name": {
#                   "default": "L. Bichsel"
#                 },
#                 "assistsToDate": 1,
#                 "sweaterNumber": 6
#               },
#               {
#                 "playerId": 8478420,
#                 "firstName": {
#                   "default": "Mikko"
#                 },
#                 "lastName": {
#                   "default": "Rantanen"
#                 },
#                 "name": {
#                   "default": "M. Rantanen"
#                 },
#                 "assistsToDate": 12,
#                 "sweaterNumber": 96
#               }
#             ],
#             "homeTeamDefendingSide": "right",
#             "isHome": false
#           },
#           {
#             "situationCode": "1551",
#             "eventId": 554,
#             "strength": "ev",
#             "playerId": 8478402,
#             "firstName": {
#               "default": "Connor"
#             },
#             "lastName": {
#               "default": "McDavid"
#             },
#             "name": {
#               "default": "C. McDavid"
#             },
#             "teamAbbrev": {
#               "default": "EDM"
#             },
#             "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8478402.png",
#             "highlightClipSharingUrlFr": "https://nhl.com/fr/video/connor-mcdavid-with-a-goal-vs-les-stars-de-dallas-6373476661112",
#             "highlightClipFr": 6373476661112,
#             "discreteClip": 6373475767112,
#             "goalsToDate": 5,
#             "awayScore": 1,
#             "homeScore": 3,
#             "leadingTeamAbbrev": {
#               "default": "EDM"
#             },
#             "timeInPeriod": "19:41",
#             "shotType": "snap",
#             "goalModifier": "none",
#             "assists": [
#               {
#                 "playerId": 8480803,
#                 "firstName": {
#                   "default": "Evan"
#                 },
#                 "lastName": {
#                   "default": "Bouchard"
#                 },
#                 "name": {
#                   "default": "E. Bouchard"
#                 },
#                 "assistsToDate": 11,
#                 "sweaterNumber": 2
#               }
#             ],
#             "homeTeamDefendingSide": "right",
#             "isHome": true
#           }
#         ]
#       },
#       {
#         "periodDescriptor": {
#           "number": 3,
#           "periodType": "REG",
#           "maxRegulationPeriods": 3
#         },
#         "goals": [
#           {
#             "situationCode": "1551",
#             "eventId": 863,
#             "strength": "ev",
#             "playerId": 8475786,
#             "firstName": {
#               "default": "Zach"
#             },
#             "lastName": {
#               "default": "Hyman"
#             },
#             "name": {
#               "default": "Z. Hyman"
#             },
#             "teamAbbrev": {
#               "default": "EDM"
#             },
#             "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8475786.png",
#             "highlightClipSharingUrl": "https://nhl.com/video/dal-edm-hyman-scores-goal-against-jake-oettinger-6373475694112",
#             "highlightClipSharingUrlFr": "https://nhl.com/fr/video/dal-edm-hyman-marque-un-but-contre-jake-oettinger-6373477061112",
#             "highlightClip": 6373475694112,
#             "highlightClipFr": 6373477061112,
#             "discreteClip": 6373477854112,
#             "discreteClipFr": 6373476959112,
#             "goalsToDate": 4,
#             "awayScore": 1,
#             "homeScore": 4,
#             "leadingTeamAbbrev": {
#               "default": "EDM"
#             },
#             "timeInPeriod": "03:25",
#             "shotType": "snap",
#             "goalModifier": "none",
#             "assists": [
#               {
#                 "playerId": 8476454,
#                 "firstName": {
#                   "default": "Ryan"
#                 },
#                 "lastName": {
#                   "default": "Nugent-Hopkins"
#                 },
#                 "name": {
#                   "default": "R. Nugent-Hopkins"
#                 },
#                 "assistsToDate": 11,
#                 "sweaterNumber": 93
#               },
#               {
#                 "playerId": 8475169,
#                 "firstName": {
#                   "default": "Evander"
#                 },
#                 "lastName": {
#                   "default": "Kane"
#                 },
#                 "name": {
#                   "default": "E. Kane"
#                 },
#                 "assistsToDate": 4,
#                 "sweaterNumber": 91
#               }
#             ],
#             "homeTeamDefendingSide": "left",
#             "isHome": true
#           },
#           {
#             "situationCode": "1551",
#             "eventId": 1039,
#             "strength": "ev",
#             "playerId": 8475786,
#             "firstName": {
#               "default": "Zach"
#             },
#             "lastName": {
#               "default": "Hyman"
#             },
#             "name": {
#               "default": "Z. Hyman"
#             },
#             "teamAbbrev": {
#               "default": "EDM"
#             },
#             "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8475786.png",
#             "highlightClipSharingUrl": "https://nhl.com/video/dal-edm-hyman-scores-goal-against-jake-oettinger-6373475988112",
#             "highlightClipSharingUrlFr": "https://nhl.com/fr/video/dal-edm-hyman-marque-un-but-contre-jake-oettinger-6373478362112",
#             "highlightClip": 6373475988112,
#             "highlightClipFr": 6373478362112,
#             "discreteClip": 6373478363112,
#             "discreteClipFr": 6373476105112,
#             "goalsToDate": 5,
#             "awayScore": 1,
#             "homeScore": 5,
#             "leadingTeamAbbrev": {
#               "default": "EDM"
#             },
#             "timeInPeriod": "12:06",
#             "shotType": "tip-in",
#             "goalModifier": "none",
#             "assists": [
#               {
#                 "playerId": 8475169,
#                 "firstName": {
#                   "default": "Evander"
#                 },
#                 "lastName": {
#                   "default": "Kane"
#                 },
#                 "name": {
#                   "default": "E. Kane"
#                 },
#                 "assistsToDate": 5,
#                 "sweaterNumber": 91
#               }
#             ],
#             "homeTeamDefendingSide": "left",
#             "isHome": true
#           },
#           {
#             "situationCode": "1451",
#             "eventId": 1124,
#             "strength": "pp",
#             "playerId": 8475906,
#             "firstName": {
#               "default": "John"
#             },
#             "lastName": {
#               "default": "Klingberg"
#             },
#             "name": {
#               "default": "J. Klingberg"
#             },
#             "teamAbbrev": {
#               "default": "EDM"
#             },
#             "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8475906.png",
#             "highlightClipSharingUrl": "https://nhl.com/video/dal-edm-klingberg-scores-goal-against-jake-oettinger-6373476604112",
#             "highlightClipSharingUrlFr": "https://nhl.com/fr/video/dal-edm-klingberg-marque-un-but-contre-jake-oettinger-6373478374112",
#             "highlightClip": 6373476604112,
#             "highlightClipFr": 6373478374112,
#             "discreteClip": 6373478067112,
#             "discreteClipFr": 6373475901112,
#             "goalsToDate": 1,
#             "awayScore": 1,
#             "homeScore": 6,
#             "leadingTeamAbbrev": {
#               "default": "EDM"
#             },
#             "timeInPeriod": "17:40",
#             "shotType": "snap",
#             "goalModifier": "none",
#             "assists": [
#               {
#                 "playerId": 8477934,
#                 "firstName": {
#                   "default": "Leon"
#                 },
#                 "lastName": {
#                   "default": "Draisaitl"
#                 },
#                 "name": {
#                   "default": "L. Draisaitl"
#                 },
#                 "assistsToDate": 15,
#                 "sweaterNumber": 29
#               },
#               {
#                 "playerId": 8475169,
#                 "firstName": {
#                   "default": "Evander"
#                 },
#                 "lastName": {
#                   "default": "Kane"
#                 },
#                 "name": {
#                   "default": "E. Kane"
#                 },
#                 "assistsToDate": 6,
#                 "sweaterNumber": 91
#               }
#             ],
#             "homeTeamDefendingSide": "left",
#             "isHome": true
#           }
#         ]
#       }
#     ],
#     "shootout": [],
#     "threeStars": [
#       {
#         "star": 1,
#         "playerId": 8479973,
#         "teamAbbrev": "EDM",
#         "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8479973.png",
#         "name": "S. Skinner",
#         "sweaterNo": 74,
#         "position": "G",
#         "goalsAgainstAverage": 1.0,
#         "savePctg": 0.971
#       },
#       {
#         "star": 2,
#         "playerId": 8475786,
#         "teamAbbrev": "EDM",
#         "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8475786.png",
#         "name": "Z. Hyman",
#         "sweaterNo": 18,
#         "position": "L",
#         "goals": 2,
#         "assists": 1,
#         "points": 3
#       },
#       {
#         "star": 3,
#         "playerId": 8476454,
#         "teamAbbrev": "EDM",
#         "headshot": "https://assets.nhle.com/mugs/nhl/20242025/EDM/8476454.png",
#         "name": "R. Nugent-Hopkins",
#         "sweaterNo": 93,
#         "position": "C",
#         "goals": 0,
#         "assists": 3,
#         "points": 3
#       }
#     ],
#     "teamGameStats": [
#       {
#         "category": "sog",
#         "awayValue": 34,
#         "homeValue": 24
#       },
#       {
#         "category": "faceoffWinningPctg",
#         "awayValue": 0.52381,
#         "homeValue": 0.47619
#       },
#       {
#         "category": "powerPlay",
#         "awayValue": "0/2",
#         "homeValue": "1/3"
#       },
#       {
#         "category": "powerPlayPctg",
#         "awayValue": 0.0,
#         "homeValue": 0.333333
#       },
#       {
#         "category": "pim",
#         "awayValue": 8,
#         "homeValue": 6
#       },
#       {
#         "category": "hits",
#         "awayValue": 30,
#         "homeValue": 46
#       },
#       {
#         "category": "blockedShots",
#         "awayValue": 17,
#         "homeValue": 21
#       },
#       {
#         "category": "giveaways",
#         "awayValue": 11,
#         "homeValue": 14
#       },
#       {
#         "category": "takeaways",
#         "awayValue": 5,
#         "homeValue": 2
#       }
#     ]
#   },
#   "periodDescriptor": {
#     "number": 3,
#     "periodType": "REG",
#     "maxRegulationPeriods": 3
#   },
#   "clock": {
#     "timeRemaining": "00:00",
#     "secondsRemaining": 0,
#     "running": false,
#     "inIntermission": false
#   }
# }

# %%
# Example: schedule for a specific date
schedule = client.schedule.get_schedule(date='2025-05-25')
print("\nSchedule:")
print(json.dumps(schedule, indent=2))
# Out:
# Schedule:
# {
#   "nextStartDate": "2025-06-01",
#   "previousStartDate": "2025-05-18",
#   "date": "2025-05-25",
#   "oddsPartners": [
#     {
#       "partnerId": 2,
#       "country": "SE",
#       "name": "Unibet",
#       "imageUrl": "https://assets.nhle.com/betting_partner/unibet.svg",
#       "siteUrl": "https://www.unibet.se/betting/sports/filter/ice_hockey/nhl/all/matches",
#       "bgColor": "#14805E",
#       "textColor": "#FFFFFF",
#       "accentColor": "#3AAA35"
#     },
#     {
#       "partnerId": 3,
#       "country": "CZ",
#       "name": "Tipsport",
#       "imageUrl": "https://assets.nhle.com/betting_partner/tipsport.svg",
#       "siteUrl": "https://www.tipsport.cz/PartnerRedirectAction.do?pid=16961&sid=20360&bid=34954&tid=11268",
#       "bgColor": "#2497F2",
#       "textColor": "#FFFFFF",
#       "accentColor": "#FFFFFF"
#     },
#     {
#       "partnerId": 6,
#       "country": "FI",
#       "name": "Veikkaus",
#       "imageUrl": "https://assets.nhle.com/betting_partner/veikkaus.svg",
#       "siteUrl": "https://www.veikkaus.fi/fi/vedonlyonti/pitkaveto?t=3-2-1_NHL",
#       "bgColor": "#0025F5",
#       "textColor": "#FFFFFF",
#       "accentColor": "#FFFFFF"
#     },
#     {
#       "partnerId": 7,
#       "country": "CA",
#       "name": "FanDuel",
#       "imageUrl": "https://assets.nhle.com/betting_partner/fanduel.svg",
#       "siteUrl": "https://fanduel.com",
#       "bgColor": "#0078ff",
#       "textColor": "#FFFFFF",
#       "accentColor": "#FFFFFF"
#     },
#     {
#       "partnerId": 8,
#       "country": "DE",
#       "name": "Sportradar",
#       "imageUrl": "https://assets.nhle.com/betting_partner/sportsradar.svg",
#       "siteUrl": "https://sportradar.com",
#       "bgColor": "#000000",
#       "textColor": "#FFFFFF",
#       "accentColor": "#E6E6E6"
#     },
#     {
#       "partnerId": 9,
#       "country": "US",
#       "name": "DraftKings",
#       "imageUrl": "https://assets.nhle.com/betting_partner/draftkings.svg",
#       "siteUrl": "https://dksb.sng.link/As9kz/rpj89?_dl=dksb%3A%2F%2Fgateway%3Fs%3D158542143&pcid=331060&psn=1320&pcn=NHLSportsbook&pscn=OddsByDK&pcrn=Static&pscid=Evergreen&pcrid=xx&wpcid=331060&wpsrc=1320&wpcn=NHLSportsbook&wpscn=OddsByDK&wpcrn=Static&wpscid=Evergreen&wpcrid=xx&_forward_params=1",
#       "bgColor": "#000000",
#       "textColor": "#FFFFFF",
#       "accentColor": "#FFFFFF"
#     },
#     {
#       "partnerId": 10,
#       "country": "SK",
#       "name": "Doxxbet",
#       "imageUrl": "https://assets.nhle.com/betting_partner/doxxbet.svg",
#       "siteUrl": "https://www.doxxbet.sk/sk/sportove-tipovanie-online/kurzy/ladovy-hokej/usa/nhl/?msID=21&mbID=27",
#       "bgColor": "#f30d31",
#       "textColor": "#202020",
#       "accentColor": "#ffffff"
#     }
#   ],
#   "games": [
#     {
#       "id": 2024030323,
#       "season": 20242025,
#       "gameType": 3,
#       "venue": {
#         "default": "Rogers Place"
#       },
#       "neutralSite": false,
#       "startTimeUTC": "2025-05-25T19:00:00Z",
#       "easternUTCOffset": "-04:00",
#       "venueUTCOffset": "-06:00",
#       "venueTimezone": "America/Edmonton",
#       "gameState": "OFF",
#       "gameScheduleState": "OK",
#       "tvBroadcasts": [
#         {
#           "id": 384,
#           "market": "N",
#           "countryCode": "US",
#           "network": "ABC",
#           "sequenceNumber": 1
#         },
#         {
#           "id": 329,
#           "market": "N",
#           "countryCode": "US",
#           "network": "ESPN+",
#           "sequenceNumber": 16
#         },
#         {
#           "id": 4,
#           "market": "N",
#           "countryCode": "CA",
#           "network": "CBC",
#           "sequenceNumber": 25
#         },
#         {
#           "id": 282,
#           "market": "N",
#           "countryCode": "CA",
#           "network": "SN",
#           "sequenceNumber": 101
#         },
#         {
#           "id": 281,
#           "market": "N",
#           "countryCode": "CA",
#           "network": "TVAS",
#           "sequenceNumber": 109
#         }
#       ],
#       "awayTeam": {
#         "id": 25,
#         "commonName": {
#           "default": "Stars"
#         },
#         "placeName": {
#           "default": "Dallas"
#         },
#         "placeNameWithPreposition": {
#           "default": "Dallas",
#           "fr": "de Dallas"
#         },
#         "abbrev": "DAL",
#         "logo": "https://assets.nhle.com/logos/nhl/svg/DAL_light.svg",
#         "darkLogo": "https://assets.nhle.com/logos/nhl/svg/DAL_dark.svg",
#         "awaySplitSquad": false,
#         "score": 1
#       },
#       "homeTeam": {
#         "id": 22,
#         "commonName": {
#           "default": "Oilers"
#         },
#         "placeName": {
#           "default": "Edmonton"
#         },
#         "placeNameWithPreposition": {
#           "default": "Edmonton",
#           "fr": "d'Edmonton"
#         },
#         "abbrev": "EDM",
#         "logo": "https://assets.nhle.com/logos/nhl/svg/EDM_light.svg",
#         "darkLogo": "https://assets.nhle.com/logos/nhl/svg/EDM_dark.svg",
#         "homeSplitSquad": false,
#         "score": 6
#       },
#       "periodDescriptor": {
#         "number": 3,
#         "periodType": "REG",
#         "maxRegulationPeriods": 3
#       },
#       "gameOutcome": {
#         "lastPeriodType": "REG"
#       },
#       "winningGoalie": {
#         "playerId": 8479973,
#         "firstInitial": {
#           "default": "S."
#         },
#         "lastName": {
#           "default": "Skinner"
#         }
#       },
#       "winningGoalScorer": {
#         "playerId": 8478402,
#         "firstInitial": {
#           "default": "C."
#         },
#         "lastName": {
#           "default": "McDavid"
#         }
#       },
#       "seriesStatus": {
#         "round": 3,
#         "seriesAbbrev": "WCF",
#         "seriesTitle": "Conference Finals",
#         "seriesLetter": "N",
#         "neededToWin": 4,
#         "topSeedTeamAbbrev": "DAL",
#         "topSeedWins": 1,
#         "bottomSeedTeamAbbrev": "EDM",
#         "bottomSeedWins": 2,
#         "gameNumberOfSeries": 3
#       },
#       "seriesUrl": "/schedule/playoff-series/2025/series-n/oilers-vs-stars",
#       "threeMinRecap": "/video/dal-at-edm-recap-6373477971112",
#       "threeMinRecapFr": "/fr/video/dal-vs-edm-25-05-2025-resume-6373476778112",
#       "condensedGame": "/video/dal-at-edm-condensed-game-6373478656112",
#       "condensedGameFr": "/fr/video/match-condense-stars-oilers-25-05-2025-6373476313112",
#       "gameCenterLink": "/gamecenter/dal-vs-edm/2025/05/25/2024030323"
#     }
#   ],
#   "numberOfGames": 1
# }

# %%
# Extract plays from play-by-play data
pd.set_option("display.max_colwidth", None)

event_types = [
    play.get('typeDescKey', None)
    for play in play_by_play_data.get('plays', {})
]
event_types_df = pd.DataFrame(event_types, columns=['event_type'])
event_types_df.value_counts().reset_index(name='count')
# Out:
#          event_type  count
# 0               hit     76
# 1           faceoff     63
# 2      shot-on-goal     51
# 3          stoppage     49
# 4      blocked-shot     42
# 5       missed-shot     29
# 6          giveaway     25
# 7              goal      7
# 8           penalty      7
# 9          takeaway      7
# 10       period-end      3
# 11     period-start      3
# 12  delayed-penalty      2
# 13         game-end      1

# %% [markdown]
# In the first development stage, we focus on the most important/ exciting events that tell about the critical in-game actions - goals, sho-on-goal, giveaway, takeaway, penalty. Further we can add the rest to enrich the detail of the same summary.

# %%
# Extract all goal events
goal_events = [
    play for play in play_by_play_data.get("plays", [])
    if play.get("typeDescKey").upper() == "GOAL"
]

print(f"\nGoal event example: \n{json.dumps(goal_events[0], indent=2)}")
# Out:
# Goal event example:
# {
#   "eventId": 320,
#   "periodDescriptor": {
#     "number": 1,
#     "periodType": "REG",
#     "maxRegulationPeriods": 3
#   },
#   "timeInPeriod": "14:02",
#   "timeRemaining": "05:58",
#   "situationCode": "1551",
#   "homeTeamDefendingSide": "left",
#   "typeCode": 505,
#   "typeDescKey": "goal",
#   "sortOrder": 219,
#   "details": {
#     "xCoord": 38,
#     "yCoord": -25,
#     "zoneCode": "O",
#     "shotType": "slap",
#     "scoringPlayerId": 8480803,
#     "scoringPlayerTotal": 6,
#     "assist1PlayerId": 8476454,
#     "assist1PlayerTotal": 9,
#     "assist2PlayerId": 8476967,
#     "assist2PlayerTotal": 3,
#     "eventOwnerTeamId": 22,
#     "goalieInNetId": 8479979,
#     "awayScore": 0,
#     "homeScore": 1,
#     "highlightClipSharingUrl": "https://nhl.com/video/dal-edm-bouchard-scores-goal-against-jake-oettinger-6373473286112",
#     "highlightClipSharingUrlFr": "https://nhl.com/fr/video/dal-edm-bouchard-marque-un-but-contre-jake-oettinger-6373473783112",
#     "highlightClip": 6373473286112,
#     "highlightClipFr": 6373473783112,
#     "discreteClip": 6373475625112,
#     "discreteClipFr": 6373473285112
#   },
#   "pptReplayUrl": "https://wsr.nhle.com/sprites/20242025/2024030323/ev320.json"
# }

# %%
# Example of accessing specific details from the first goal event
goal_events[0].get("details").get("scoringPlayerId")
# Out:
# 8480803

# %% [markdown]
# From the goal dictionary, we extract and reshape key details

# %%
def interpret_goal(event: Dict[str, Any]) -> Dict[str, Any]:
    details = event.get("details", {})
    period = event.get("periodDescriptor", {}).get("number")
    time = event.get("timeInPeriod")

    return {
        "event_type": "goal",
        "players": {
            "scorer_id": details.get("scoringPlayerId"),
            "assist_ids": [
                details.get("assist1PlayerId"),
                details.get("assist2PlayerId")
            ]
        },
        "goalie_id": details.get("goalieInNetId"),
        "team_id": details.get("eventOwnerTeamId"),
        "score": {
            "home": details.get("homeScore", 0),
            "away": details.get("awayScore", 0)
        },
        "period": period,
        "time": time,
        "zone": details.get("zoneCode"),
        "shot_type": details.get("shotType"),
        "location": {
            "x": details.get("xCoord"),
            "y": details.get("yCoord")
        },
        "highlight": details.get("highlightClipSharingUrl")
    }

# %% [markdown]
# Test the function on the goal events we saved earlier.

# %%
normalised_goals = [interpret_goal(goal) for goal in goal_events]
normalised_goals[0]
# Out:
# {'event_type': 'goal',
#  'players': {'scorer_id': 8480803, 'assist_ids': [8476454, 8476967]},
#  'goalie_id': 8479979,
#  'team_id': 22,
#  'score': {'home': 1, 'away': 0},
#  'period': 1,
#  'time': '14:02',
#  'zone': 'O',
#  'shot_type': 'slap',
#  'location': {'x': 38, 'y': -25},
#  'highlight': 'https://nhl.com/video/dal-edm-bouchard-scores-goal-against-jake-oettinger-6373473286112'}
